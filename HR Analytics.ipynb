# %% [markdown]
# # HR Analytics

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
hr_data = pd.read_csv("/Users/adityaagarwal/Aditya Ag/Jupyter Notebook/Data Science Projects/HR Analytics For Green Destinations Using Tableau/HR Analytics/greendestination.csv")
hr_data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
# Checking the columns
hr_data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
hr_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
hr_data[hr_data['Department']!= 'Research & Development']
# Out:
#       Age Attrition     BusinessTravel  DailyRate Department  \
# 0      41       Yes      Travel_Rarely       1102      Sales
# 18     53        No      Travel_Rarely       1219      Sales
# 21     36       Yes      Travel_Rarely       1218      Sales
# 27     42        No      Travel_Rarely        691      Sales
# 29     46        No      Travel_Rarely        705      Sales
# ...   ...       ...                ...        ...        ...
# 1454   45        No      Travel_Rarely        374      Sales
# 1461   50       Yes      Travel_Rarely        410      Sales
# 1462   39        No      Travel_Rarely        722      Sales
# 1464   26        No      Travel_Rarely       1167      Sales
# 1468   49        No  Travel_Frequently       1023      Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 18                   2          4  Life Sciences              1
# ...

# %%
# Checking for categorical Variables
hr_data.select_dtypes(include='object')
# Out:
#      Attrition     BusinessTravel              Department EducationField  \
# 0          Yes      Travel_Rarely                   Sales  Life Sciences
# 1           No  Travel_Frequently  Research & Development  Life Sciences
# 2          Yes      Travel_Rarely  Research & Development          Other
# 3           No  Travel_Frequently  Research & Development  Life Sciences
# 4           No      Travel_Rarely  Research & Development        Medical
# ...        ...                ...                     ...            ...
# 1465        No  Travel_Frequently  Research & Development        Medical
# 1466        No      Travel_Rarely  Research & Development        Medical
# 1467        No      Travel_Rarely  Research & Development  Life Sciences
# 1468        No  Travel_Frequently                   Sales        Medical
# 1469        No      Travel_Rarely  Research & Development        Medical
#
#       Gender                    JobRole MaritalStatus Over18 OverTime
# ...

# %%
hr_data['BusinessTravel']
# Out:
# 0           Travel_Rarely
# 1       Travel_Frequently
# 2           Travel_Rarely
# 3       Travel_Frequently
# 4           Travel_Rarely
#               ...
# 1465    Travel_Frequently
# 1466        Travel_Rarely
# 1467        Travel_Rarely
# 1468    Travel_Frequently
# 1469        Travel_Rarely
# Name: BusinessTravel, Length: 1470, dtype: object

# %%
sns.countplot(data=hr_data, x = 'BusinessTravel', hue='Attrition')
# Out:
# <AxesSubplot:xlabel='BusinessTravel', ylabel='count'>

# %%
plt.figure(figsize=(15,3))
sns.barplot(data=hr_data, x = 'EducationField', y = 'YearsAtCompany', hue = 'Attrition')
plt.show()

# %%
sns.set_theme(style="white", context="talk")
plt.figure(figsize=(20,3))
sns.barplot(data=hr_data, x = 'JobRole', y = 'YearsAtCompany', hue = 'Attrition')
#sns.set_xticklabels(sns.get_xticklabels(), rotation = 45)
plt.show()

# %% [markdown]
# #### Understanding all the variables:

# %%
hr_data.Age.plot(kind = 'hist')
print(hr_data.Age.mean())
# Out:
# 36.923809523809524

# %% [markdown]
# Age is normally distributed with mean as `36.92`

# %%
hr_data.Attrition
# Out:
# 0       Yes
# 1        No
# 2       Yes
# 3        No
# 4        No
#        ...
# 1465     No
# 1466     No
# 1467     No
# 1468     No
# 1469     No
# Name: Attrition, Length: 1470, dtype: object

# %%
business_count = hr_data.BusinessTravel.value_counts()
print(business_count)
business_count.plot(kind = 'bar')
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64
# <AxesSubplot:>
